# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = float(input("실수 입력 : "))

print("정수 첫째 짜리 : ", int(n)%10)
print("소수 첫째 자리 : ", int(n*10)%10)
# Out:
# 실수 입력 : 12345.678
# 정수 첫째 짜리 :  5
# 소수 첫째 자리 :  6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
year = int(input("년 입력 : "))

if year%4 == 0 and year%100 != 0 or year%400 == 0:
  print("윤년 ==> 366일")
else:
  print("평년 ==> 365일")
# Out:
# 년 입력 : 2024
# 윤년 ==> 366일

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def round_func(number):
  num_upper = number * 10
  if number > 0:
    if num_upper % 10 >= 5:
      return int(number) + 1
    else:
      return int(number)
  else:
    if num_upper % 10 <= 5:
      return int(number) - 1
    else:
      return int(number)


fl = float(input("실수 입력 : "))
print(round_func(fl))
# Out:
# 실수 입력 : 3.4
# 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a, b = map(int, (input("숫자 입력 : ")).split())

print("산술평균 : ", (a+b)/2)
print("기하평균 : ", (a*b)**0.5)
print("조화평균 : ", 2*a*b/(a+b))
# Out:
# 숫자 입력 : 10 15
# 산술평균 :  12.5
# 기하평균 :  12.24744871391589
# 조화평균 :  12.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math

def func(a, b, c):
    # 판별식 계산
    discriminant = b**2 - 4*a*c

    # 판별식이 0보다 크거나 같은 경우에만 해를 계산
    if discriminant > 0:
        root1 = (-b + math.sqrt(discriminant)) / (2*a)
        root2 = (-b - math.sqrt(discriminant)) / (2*a)
        return f"두 실근 : {root1}, {root2}"
    elif discriminant == 0:
        root = -b / (2*a)
        return f"중근 : {root}"
    else:
        return "근이 없음"

a, b, c = map(float, input("이차방정식 계수 입력 : ").split())
print(func(a, b, c))
# Out:
# 이차방정식 계수 입력 : 1 -2 -3
# 두 실근 : 3.0, -1.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a, b, c = map(int, (input("세 정수 입력 : ")).split())
lst = [a, b, c]
lst = sorted(lst)
print(lst[1])
# Out:
# 세 정수 입력 : 3 9 6
# 6

# %%
def func(a, b, c):
    if a > b and a < c or a < b and a > c:
        return a
    elif b > a and b < c or b < a and b > c:
        return b
    else:
        return c

a, b, c = map(int, (input("세 정수 입력 : ")).split())
print(func(a, b, c))
# Out:
# 세 정수 입력 : 16 12 18
# 16

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def func(a, b, c):
    if a > b and a < c or a < b and a > c:
        return a
    elif b > a and b < c or b < a and b > c:
        return b
    else:
        return c

def func_lst(a, b, c):
  # 가장 작은 수 출력
  if a < b and a < c: # a가 가장 작은 수
    print(a, end=" ")
  elif b < a and b < c: # b가 가장 작은 수
    print(b, end=" ")
  else:
    print(c, end=" ")

  # 중간 수 출력
  print(func(a, b, c), end=" ")

  # 가장 큰 수 출력
  if a > b and a > c: # a가 가장 큰 수
    print(a)
  elif b > a and b > c: # b가 가장 큰 수
    print(b)
  else:
    print(c)

a, b, c = map(int, (input("세 정수 입력 : ")).split())
func_lst(a, b, c)
# Out:
# 세 정수 입력 : 3 9 6
# 3 6 9

# %%
def bubble_sort(numbers):
    for i in range(len(numbers)):
        for j in range(len(numbers) - 1):
            if numbers[j] > numbers[j + 1]: # 현재 요소가 다음 요소보다 크다면
                numbers[j], numbers[j + 1] = numbers[j + 1], numbers[j] # 두 요소의 위치를 바꿈
    return numbers

numbers = list(map(int, input("세 정수 입력 : ").split()))
sorted_numbers = bubble_sort(numbers)
print("정렬된 숫자 : ", sorted_numbers)
# Out:
# 세 정수 입력 : 3 9 6
# 정렬된 숫자 :  [3, 6, 9]
